# %%
import get_info_YT as gt

# %%
url1 = 'https://www.youtube.com/@WeightliftingHouse'

# %%
channel1 = gt.InfoYT(url1)
channel1.get_info()
# Out:
# The username for this channel is: Weightlifting House.
# The channel id is: UCd5WxLFvKjEbJl5xyUqyHSw
# The number of video published by this channel is: 1054.

# %%
channel1.get_recent_videos(max_result=5)
# Out:
# [{'video_id': '6iI7D0Yhs2s',
#   'title': '180kg Power Clean vs 200kg Clean & Jerk by Rahmat 🤯🏋️\u200d♀️ #weightlifting #olympicweightlifting',
#   'published_at': '2024-06-18T16:26:45Z',
#   'duration': 'PT30S',
#   'description': '',
#   'timestamps': None},
#  {'video_id': 'AbUnYaUfIGc',
#   'title': 'From the Backroom to the Platform | Shi vs Rahmat vs Rizki',
#   'published_at': '2024-06-11T13:34:51Z',
#   'duration': 'PT13M31S',
# ...

# %%
url2 = 'https://www.youtube.com/@3blue1brown/videos'

# %%
channel2 = gt.InfoYT(url2)
channel2.get_info()
# Out:
# The username for this channel is: 3Blue1Brown.
# The channel id is: UCYO_jab_esuFRV4b17AJtAw
# The number of video published by this channel is: 177.

# %%
videos = channel2.get_recent_videos(max_result=3)
for video in videos:
    print(video)
# Out:
# {'video_id': 'rjVY7HXN6qA', 'title': 'In the vector space of all advice...', 'published_at': '2024-05-22T17:56:07Z', 'duration': 'PT57S', 'description': 'A link to the full video is on the screen, or here for reference: https://youtu.be/W3I3kAg2J7w', 'timestamps': None}
# ...

# %%
url3 = 'https://www.youtube.com/watch?v=vsa9GGzMFXQ'

# %%
channel3 = gt.InfoYT(url3)
channel3.get_info()
# Out:
# The username for this channel is: Keith Galli.
# The channel id is: UCq6XkhO5SZ66N04IcPbqNcw
# The number of video published by this channel is: 87.

# %%
channel3.check_history()
# Out:
# The file Keith_Galli_videos.json already exists.
# True

# %%
if not channel3.check_history():
    all_videos = channel3.get_all_videos_from_channel()
    if all_videos:
        print(len(videos))
# Out:
# The file Keith_Galli_videos.json already exists.

# %%
channel3.load_from_json()
channel3.all_videos
# Out:
# {'DcI_AZqfZVc': {'video_id': 'DcI_AZqfZVc',
#   'title': 'Advanced Web Scraping Tutorial! (w/ Python Beautiful Soup Library)',
#   'published_at': '2024-06-08T13:57:23Z',
#   'duration': 'PT42M43S',
# ...

# %%
channel3.get_dates()
print(channel3.most_recent_date)
print(channel3.oldest_date)
# Out:
# 2024-06-08 13:57:23
# 2016-12-27 21:12:20
